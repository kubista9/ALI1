# %%
from sympy import *
from sympy import Rational as R
import numpy as np
from IPython.display import display, Latex, HTML, Math
init_printing()

# %%
import numpy as np

def scalar_projection(u1, x):
    """
    Calculate the scalar projection of vector x onto vector u1.
    
    Args:
    u1 (array-like): The first vector.
    x (array-like): The second vector.
    
    Returns:
    float: The scalar projection of x onto u1.
    """
    # Calculate the scalar projection component
    scalar_projection = u1.dot(x) / u1.dot(u1) 
    
    return scalar_projection

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
u = Matrix([-1, 2])
v = Matrix([4, 6])

u.dot(u), u.dot(v), (v.dot(u)) / u.dot(u)
# Out:
# (5, 8, 8/5)

# %%
# 6.1.7
v = Matrix([[R(7, 4)],[R(1, 2)],[1]])
v.normalized(), 1/v.norm() *v, v/v.norm()
# Out:
# ⎛⎡7⋅√69⎤  ⎡7⋅√69⎤  ⎡7⋅√69⎤⎞
# ⎜⎢─────⎥  ⎢─────⎥  ⎢─────⎥⎟
# ⎜⎢  69 ⎥  ⎢  69 ⎥  ⎢  69 ⎥⎟
# ⎜⎢     ⎥  ⎢     ⎥  ⎢     ⎥⎟
# ⎜⎢2⋅√69⎥  ⎢2⋅√69⎥  ⎢2⋅√69⎥⎟
# ⎜⎢─────⎥, ⎢─────⎥, ⎢─────⎥⎟
# ⎜⎢  69 ⎥  ⎢  69 ⎥  ⎢  69 ⎥⎟
# ⎜⎢     ⎥  ⎢     ⎥  ⎢     ⎥⎟
# ⎜⎢4⋅√69⎥  ⎢4⋅√69⎥  ⎢4⋅√69⎥⎟
# ⎜⎢─────⎥  ⎢─────⎥  ⎢─────⎥⎟
# ⎝⎣  69 ⎦  ⎣  69 ⎦  ⎣  69 ⎦⎠

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x, y = Matrix([10, -3]), Matrix([-1, -5])
(x-y).norm(), float((x-y).norm()), (x-y).norm().evalf(6), round((x-y).norm(), 4)
# Out:
# (5⋅√5, 11.180339887498949, 11.1803, 11.1803)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
U = Matrix([[-1,4,-3],[5,2,1],[3,-4,-7]]).T

U.T*U
# Out:
# ⎡26  0   2 ⎤
# ⎢          ⎥
# ⎢0   30  0 ⎥
# ⎢          ⎥
# ⎣2   0   74⎦

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
U = Matrix([[1,0,1], [-1,4,1], [2,1,-2]]).T
x = Matrix([[8],[-4],[-3]])

u1, u2, u3 = U[:, 0], U[:, 1], U[:, 2]
a1 = x.project(u1)
a2 = x.project(u2)
a3 = x.project(u3)

display(Latex("$$x = {} + {} + {}$$".format(latex(a1), latex(a2), latex(a3))))
# Out:
# $$x = \left[\begin{matrix}\frac{5}{2}\\0\\\frac{5}{2}\end{matrix}\right] + \left[\begin{matrix}\frac{3}{2}\\-6\\- \frac{3}{2}\end{matrix}\right] + \left[\begin{matrix}4\\2\\-4\end{matrix}\right]$$

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
v = Matrix([1, -1])
u = Matrix([-1, 3])

v.project(u) # project v onto u
# Out:
# ⎡2/5 ⎤
# ⎢    ⎥
# ⎣-6/5⎦

# %%
U = Matrix([[1/sqrt(10),3/sqrt(20),3/sqrt(20)],
           [3/sqrt(10),-1/(sqrt(20)),-1/sqrt(20)],
           [0,-1/sqrt(2),1/sqrt(2)]])
U, U.T * U
# Out:
# ⎛⎡ √10   3⋅√5  3⋅√5⎤           ⎞
# ⎜⎢ ───   ────  ────⎥           ⎟
# ⎜⎢  10    10    10 ⎥           ⎟
# ⎜⎢                 ⎥  ⎡1  0  0⎤⎟
# ⎜⎢3⋅√10  -√5   -√5 ⎥  ⎢       ⎥⎟
# ⎜⎢─────  ────  ────⎥, ⎢0  1  0⎥⎟
# ⎜⎢  10    10    10 ⎥  ⎢       ⎥⎟
# ⎜⎢                 ⎥  ⎣0  0  1⎦⎟
# ⎜⎢       -√2    √2 ⎥           ⎟
# ⎜⎢  0    ────   ── ⎥           ⎟
# ⎝⎣        2     2  ⎦           ⎠

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A=Matrix([[-6,-3,6,1],[-1,2,1,-6],[3,6,3,-2],[6,-3,6,-1],[2,-1,2,3],[-3,6,3,2],[-2,-1,2,-3],[1,2,1,6]])

A.T * A
# Out:
# ⎡100   0    0    0 ⎤
# ⎢                  ⎥
# ⎢ 0   100   0    0 ⎥
# ⎢                  ⎥
# ⎢ 0    0   100   0 ⎥
# ⎢                  ⎥
# ⎣ 0    0    0   100⎦

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
U = vec2mat([[0],[1],[-4],[-1]], [[3],[5],[1],[1]], [[1],[0],[1],[-4]], [[5],[-3],[-1],[1]])
u1, u2, u3, u4 = U[:,0], U[:,1], U[:,2], U[:,3]

x = Matrix([[10],[-8],[2],[0]])

z1 = x.project(u1) + x.project(u2) + x.project(u3)
z2 = x.project(u4)

display(Latex("$$x = {} + {}$$".format(latex(z1), latex(z2))))
# Out:
# $$x = \left[\begin{matrix}0\\-2\\4\\-2\end{matrix}\right] + \left[\begin{matrix}10\\-6\\-2\\2\end{matrix}\right]$$

# %%
z1 = x - z2
z1
# Out:
# ⎡0 ⎤
# ⎢  ⎥
# ⎢-2⎥
# ⎢  ⎥
# ⎢4 ⎥
# ⎢  ⎥
# ⎣-2⎦

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
y, u1, u2 = Matrix([[1],[3],[5]]), Matrix([[1],[3],[-2]]), Matrix([[5],[1],[4]])

y.project(u1) + y.project(u2)
# Out:
# ⎡10/3⎤
# ⎢    ⎥
# ⎢2/3 ⎥
# ⎢    ⎥
# ⎣8/3 ⎦

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
z, v1, v2 = Matrix([[3],[-7],[2],[3]]), Matrix([[2],[-1],[-3],[1]]), Matrix([[1],[1],[0],[-1]])

scalar_projection(v1, z), scalar_projection(v2, z)
# Out:
# (2/3, -7/3)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
y, u1, u2 = Matrix([[4],[8],[1]]), Matrix([R(2,3),R(1,3),R(2,3)]), Matrix([R(-2,3),R(2,3),R(1,3)])

U = Matrix.hstack(u1, u2)

U.T * U, U*U.T
# Out:
# ⎛        ⎡8/9   -2/9  2/9⎤⎞
# ⎜⎡1  0⎤  ⎢               ⎥⎟
# ⎜⎢    ⎥, ⎢-2/9  5/9   4/9⎥⎟
# ⎜⎣0  1⎦  ⎢               ⎥⎟
# ⎝        ⎣2/9   4/9   5/9⎦⎠

# %%
y.project(u1) + y.project(u2), U*U.T *  y
# Out:
# ⎛⎡2⎤  ⎡2⎤⎞
# ⎜⎢ ⎥  ⎢ ⎥⎟
# ⎜⎢4⎥, ⎢4⎥⎟
# ⎜⎢ ⎥  ⎢ ⎥⎟
# ⎝⎣5⎦  ⎣5⎦⎠

# %%
X = Matrix([[1,np.log(44)],[1,np.log(61)],[1,np.log(81)],[1,np.log(113)],[1,np.log(131)]])

p = Matrix([[91],[98],[103],[110],[112]])

(X.T * X).evalf(6), (X.T * p).evalf(6)

(Matrix.hstack((X.T * X), (X.T * p)).rref()[0]).evalf(6)
# Out:
# ⎡1.0   0   17.9243⎤
# ⎢                 ⎥
# ⎣ 0   1.0  19.385 ⎦
